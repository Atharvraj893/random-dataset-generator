# %%
import numpy as np
import pandas as pd
import random as rd
from faker import Faker

# %%
print("What type of dataset you want :\n1. Student marks\n2. Employee salary\n3. Sales dataset")
dt = int(input("Enter your choice from 1/2/3 = "))
if dt==1:
    di = {}
    print("You get Student marks data with study hour and marks of 5 subjects and name of student")
    row = int(input("Enter how many rows you want : "))
    for i in range(row+1):
        sh = rd.randint(1,10)
        Chemistry = (sh*10)+rd.randint(-5,5)
        Physics = (sh*10)+rd.randint(-5,5)
        Computer = (sh*10)+rd.randint(-5,5)
        English = (sh*10)+rd.randint(-5,5)
        Maths = (sh*10)+rd.randint(-5,5)
        value = [sh,Physics,Chemistry,Computer,English,Maths]
        fake = Faker("en_IN")
        n = fake.name()
        di[n] = value
    df = pd.DataFrame.from_dict(di,orient="index",columns = ["Study Hour","Physics","Chemistry","Computer","English","Maths"])
    print(df)
# Out:
# What type of dataset you want :
# 1. Student marks
# 2. Employee salary
# 3. Sales dataset
# Enter your choice from 1/2/3 =  1
# You get Student marks data with study hour and marks of 5 subjects and name of student
# Enter how many rows you want :  10
#                      Study Hour  Physics  Chemistry  Computer  English  Maths
# Tejas Goda                    6       59         61        59       64     64
# Laban Sachdeva                6       56         59        63       57     65
# Pooja Sharma                 10      102        104       102      101    101
# Sudiksha Edwin                7       67         75        75       72     74
# Fitan Kala                    5       52         54        45       48     48
# Onveer Karpe                  8       80         81        85       80     79
# Oviya Tara                    5       50         47        46       49     51
# Girik Bedi                    7       70         75        70       66     67
# Tanmayi Bajwa                 6       63         60        63       55     60
# Vedika Balakrishnan           3       35         25        35       30     32
# Ubika Modi                    9       86         90        92       85     90
